# %%
from datasets import Dataset 
import os
from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness

# os.environ["OPENAI_API_KEY"] = "your-openai-key"
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv()) 

data_samples = {
    'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
    'answer': ['The first superbowl was held on Jan 15, 1967', 'The most super bowls have been won by The New England Patriots'],
    'contexts' : [['The First AFL–NFL World Championship Game was an American football game played on January 15, 1967, at the Los Angeles Memorial Coliseum in Los Angeles,'], 
    ['The Green Bay Packers...Green Bay, Wisconsin.','The Packers compete...Football Conference']],
    'ground_truth': ['The first superbowl was held on January 15, 1967', 'The New England Patriots have won the Super Bowl a record six times']
}

dataset = Dataset.from_dict(data_samples)

score = evaluate(dataset,metrics=[faithfulness,answer_correctness])
print(score.to_pandas())
# Out:
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#                          question  \
# 0  When was the first super bowl?
# 1   Who won the most super bowls?
#
#                                               answer  \
# 0       The first superbowl was held on Jan 15, 1967
# 1  The most super bowls have been won by The New ...
#
#                                             contexts  \
# 0  [The First AFL–NFL World Championship Game was...
# 1  [The Green Bay Packers...Green Bay, Wisconsin....
#
#                                         ground_truth  faithfulness  \
# 0   The first superbowl was held on January 15, 1967           0.0
# 1  The New England Patriots have won the Super Bo...           0.0
#
#    answer_correctness
# 0            0.749095
# 1            0.731078

# %%
import pandas as pd
df = pd.read_csv("evaluation_questions.csv")
df
# Out:
#                                             Questions  \
# 0   How many countries and areas were enrolled in ...
# 1   What are the strategic objectives of the globa...
# 2   How many countries have developed their own na...
# 3   Which sector in One health would be influenced...
# 4                                 What is One Health?
# 5             What is antimicrobial resistance (AMR)?
# 6   Is it still possible to control antimicrobial ...
# 7   What are the issues with financing in controll...
# 8     What is the status of MRSA infection in Europe?
# 9   Which regions will be disproportionally affect...
# 10  What are the options for strengthening AMR sur...
# 11  Where is the majority of handling AMR finance ...
# 12  Are there Sustainable Development Goals (SDGs)...
# 13  Are there new emerging antimicrobial resistanc...
# 14  Which countries monitor or plan to monitor the...
# 15  Which countries monitor or plan to monitor ant...
# 16  What antimicrobial-resistant bacterial infecti...
# 17  Which antimicrobial-resistant bacterial infect...
#
#                                          Groud_answer  Difficulty
# 0   By the end of the 2021, 109 countries plus two...           2
# 1   there are five main obejectives: to improve aw...           2
# 2   Up to 2021-22, there are 149 countries release...           2
# 3   All sectors of One Health would be influenced ...           3
# 4   One Health is an integrated, unifying approach...           1
# 5   AMR occurs when microorganisms, such as bacter...           1
# 6   Yes. But it requires multisectoral and multidi...           5
# 7   The financing challenges associated with comba...           5
# 8   For S. aureus, a significant decrease in the E...           5
# 9   Low- and middle-income countries such as Afric...           5
# 10  Deepening engagement with global and regional ...           5
# 11  Much of finaicial support is used to fund rese...           5
# 12  Yes.  It inculdes SDG indicator 3.d.2 and SDG ...           3
# 13  Yes, new emerging antimicrobial resistance (AM...           5
# 14  Yes. For example, the USA planed to strengthen...           4
# 15        Guinea-Bissau, the UK, the USA, and Canada.           4
# 16  Infections caused by antimicrobial-resistant E...           3
# 17  Escherichia coli and Staphylococcus aureus are...           3

# %%
from vectordb_utils_shule import ShuleVectorDB
from prompt_utils import build_prompt
import pickle
import importlib
# importlib.reload(openai_utils)
# from openai_utils import get_completion_openai, init_openai

index_path = "../index/index_n179366_03171945.pickle"
top_n = 8
recall_n = 80

init_openai()
with open(index_path, 'rb') as file:
        vec_db_shule = pickle.load(file)
    
def search_db(user_input, source_type):
    search_results = []
    
    if search_strategy == "hnsw":
        search_labels = vec_db_shule.search_bge(user_input, top_n)
        texts, pages, titles, years, countries, ORGs = vec_db_shule.get_context_by_labels(search_labels)
        search_results = texts
        res = [texts[i] if countries[i] == 'xxx' else f'In {countries[i]}, {texts[i]}' for i in range(top_n)]

        search_field = "\n\n".join([f"{i+1}. [Reference: {titles[i]}, Page: {pages[i]}, ORG: {ORGs[i]}, Year: {years[i]}]\n{texts[i]}" for i in range(top_n)])
        prompt = build_prompt(source_type=source_type, info=[f"{res[i]} [Reference: Page {pages[i]}, {titles[i]}, {years[i]}, {ORGs[i]}]" for i in range(top_n)], query=user_input)
        
    elif search_strategy == "rerank":
        scores, texts, pages, titles, years, countries, ORGs = rerank(user_input, top_n, recall_n)
        search_results = texts
        res = [texts[i] if countries[i] == 'xxx' else f'In {countries[i]}, {texts[i]}' for i in range(top_n)]

        search_field = "\n\n".join([f"{i+1}. [Reference: {titles[i]}, Page: {pages[i]}, ORG: {ORGs[i]}, Year: {years[i]}]\n{texts[i]}" for i in range(top_n)])
        prompt = build_prompt(source_type=source_type, info=[f"{res[i]} [Reference: Page {pages[i]}, {titles[i]}, {years[i]}, {ORGs[i]}]" for i in range(top_n)], query=user_input)
        
    elif search_strategy == "fusion":
        log_warning("Not support yet.")
        return
            
    log_info(f"prompt content built:\n{prompt}")
    return prompt, search_results


def rerank(user_input, top_n, recall_n):
    search_labels = vec_db_shule.search_bge(user_input, recall_n)
    t0 = time.time()
    texts, pages, titles, years, countries, ORGs = vec_db_shule.get_context_by_labels(search_labels)
    t1 = time.time()
    log_info(f"vec_db_shule.get_context_by_labels costs: {t1 - t0}")

    documents = [texts[i] if countries[i] == 'xxx' else f'In {countries[i]}, {texts[i]}' for i in range(len(pages))]
    res = rerank_model.rank(documents = documents,
                            query=user_input,
                            batch_size = 1,
                            return_documents = False,
                            show_progress_bar = False)
    t2 = time.time()
    log_info(f"rerank_model.predict costs: {t2 - t1}")
    
    ids = [i['corpus_id'] for i in res][:top_n]
    scores = [i['score'] for i in res][:top_n]

    log_info(f"finish rerank {recall_n} texts, return highest {top_n} texts")
    return scores, [texts[i] for i in ids], [pages[i] for i in ids], [titles[i] for i in ids], [years[i] for i in ids], [countries[i] for i in ids], [ORGs[i] for i in ids]

# %%
questions = df["Questions"].to_list()
ground_truths = df["Groud_answer"].to_list()
answers = []
contexts = []
retrieve_time = []
completion_time = []

# %%
from logger import log_info
import importlib
import openai_utils
import time
# 在需要重新加载的地方调用 reload() 函数
importlib.reload(openai_utils)
from openai_utils import get_completion_openai, init_openai

search_strategy = "hnsw"
source = "Hybrid"
model= "GPT-3.5"

init_openai()
for i, query in enumerate(questions[:2]):
    print(i, "begins")
    t0 = time.time()
    prompt, search_results = search_db(query, source)
    t1 = time.time()
    response = get_completion_openai(prompt, model=model)
    t2 = time.time()
    contexts.append(search_results) 
    answers.append(response)
    retrieve_time.append(t1 - t0)
    completion_time.append(t2 - t1)
# Out:
# 0 How many countries and areas were enrolled in GLASS-AMR? begins
# 1 What are the strategic objectives of the global action plan (GAP) on antimicrobial resistance (AMR) in 2015? begins

# %%
data = {
    "question": questions,
    "answer": answers,
    "contexts": contexts,
    "ground_truth": ground_truths
}
dataset = Dataset.from_dict(data)

# %%
data = {
    "question": questions,
    "answer": answers,
    "contexts": contexts,
    "ground_truth": ground_truths,
    "retrieve_time": retrieve_time,
    "completion_time": completion_time, 
}
dataset = Dataset.from_dict(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 7
#       1 select = 2
#       2 data = {
#       3     "question": questions[:select],
#       4     "answer": answers[:select],
#       5     "contexts": contexts[:select],
#       6     "ground_truth": ground_truths[:select],
# ----> 7     "retrieve_time": retrieve_time[:select],
#       8     "completion_time": completion_time[:select],
#       9 }
#      10 dataset = Dataset.from_dict(data)
#
# NameError: name 'retrieve_time' is not defined

# %%
questions[:2]
# Out:
# ['How many countries and areas were enrolled in GLASS-AMR?',
#  'What are the strategic objectives of the global action plan (GAP) on antimicrobial resistance (AMR) in 2015?']

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    context_relevancy,
    context_entity_recall,
    answer_similarity
)

result = evaluate(
    dataset = dataset,
    metrics=[context_precision,
            context_recall,
            faithfulness,
            answer_relevancy,
            context_relevancy,
            context_entity_recall,
            answer_similarity],
    raise_exceptions=False
)

df = result.to_pandas()
# Out:
# Evaluating:   0%|          | 0/72 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 10
#       1 from ragas import evaluate
#       2 from ragas.metrics import (
#       3     faithfulness,
#       4     answer_relevancy,
#    (...)
#       7     context_relevancy,
#       8 )
# ---> 10 result = evaluate(
#      11     dataset = dataset,
#      12     metrics=[context_precision,
#      13             context_recall,
#      14             faithfulness,
#      15             answer_relevancy,],
#      16     raise_exceptions=False
#      17 )
#      19 df = result.to_pandas()
#
# File ~/.local/lib/python3.10/site-packages/ragas/evaluation.py:211, in evaluate(dataset, metrics, llm, embeddings, callbacks, is_async, run_config, raise_exceptions, column_map)
#     208 scores = []
#     209 try:
#     210     # get the results
# --> 211     results = executor.results()
#     212     if results == []:
#     213         raise ExceptionInRunner()
#
# File ~/.local/lib/python3.10/site-packages/ragas/executor.py:132, in Executor.results(self)
#     130 executor_job.start()
#     131 try:
# --> 132     executor_job.join()
#     133 finally:
#     134     ...
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Exception in thread Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Runner(Thread-11, stopped 140307882550848)>>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.10/threading.py", line 1018, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/usr/lib/python3.10/threading.py", line 1336, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket

# %%
df2 = df
df2
# Out:
#                                              question  \
# 0   How many countries and areas were enrolled in ...
# 1   What are the strategic objectives of the globa...
# 2   How many countries have developed their own na...
# 3   Which sector in One health would be influenced...
# 4                                 What is One Health?
# 5             What is antimicrobial resistance (AMR)?
# 6   Is it still possible to control antimicrobial ...
# 7   What are the issues with financing in controll...
# 8     What is the status of MRSA infection in Europe?
# 9   Which regions will be disproportionally affect...
# 10  What are the options for strengthening AMR sur...
# 11  Where is the majority of handling AMR finance ...
# 12  Are there Sustainable Development Goals (SDGs)...
# 13  Are there new emerging antimicrobial resistanc...
# 14  Which countries monitor or plan to monitor the...
# 15  Which countries monitor or plan to monitor ant...
# 16  What antimicrobial-resistant bacterial infecti...
# 17  Which antimicrobial-resistant bacterial infect...
#
#                                                answer  \
# 0   Based on the information provided, as of today...
# 1   The strategic objectives of the global action ...
# 2   Based on available data, more than 115 countri...
# 3   The sector in One Health that would be influen...
# 4   One Health is a collaborative, multisectoral, ...
# 5   Antimicrobial resistance (AMR) refers to the a...
# 6   Yes, it is still possible to control antimicro...
# 7   The issues with financing in controlling antim...
# 8   The status of MRSA infection in Europe varies ...
# 9   Regions that will be disproportionately affect...
# 10  In developing countries, strengthening antimic...
# 11  The majority of financing for handling antimic...
# 12  Yes, there are Sustainable Development Goals (...
# 13  Yes, in Europe, there are indeed emerging anti...
# 14  Based on available information, several countr...
# 15                    There's not enough information.
# 16  The antimicrobial-resistant bacterial infectio...
# 17  In Europe, bloodstream infections are primaril...
#
#                                              contexts  \
# 0   [AMR findings are thus presented and 1.3 Key f...
# 1   [In 2015, recognizing the urgent need to tackl...
# 2   [Executive summary Since the Global Action Pla...
# 3   [Introduction WHO implementation handbook for ...
# 4   [2 ‘One Health’ is an approach to designing an...
# 5   [Antimicrobial resistance in livestock in the ...
# 6   [SURVEILLANCE REPORT Antimicrobial resistance ...
# 7   [Insufficient funding devoted to AMR is anothe...
# 8   [MRSA is currently the most commonly The propo...
# 9   [It has been estimated that failure to address...
# 10  [Updates from WHO Regional Offices on AMR surv...
# 11  [Despite this, only 57% (12/21) of the AMR-NAP...
# 12  [HOW DOES AMR IMPACT THE SDGS? Addressing AMR ...
# 13  [Other new mechanisms of antimicrobial resista...
# 14  [Global Antimicrobial Resistance Surveillance ...
# 15  [for Infectious Diseases (APFID). ANSORP inclu...
# 16  [. . . . . . . . . . . . . . . . . . . . . . ....
# 17  [uginosa and Acinetobacter spp. bloodstream in...
#
#                                          ground_truth  context_precision  \
# 0   By the end of the 2021, 109 countries plus two...           1.000000
# 1   there are five main obejectives: to improve aw...           1.000000
# 2   Up to 2021-22, there are 149 countries release...           1.000000
# 3   All sectors of One Health would be influenced ...           1.000000
# 4   One Health is an integrated, unifying approach...           1.000000
# 5   AMR occurs when microorganisms, such as bacter...           1.000000
# 6   Yes. But it requires multisectoral and multidi...           1.000000
# 7   The financing challenges associated with comba...           1.000000
# 8   For S. aureus, a significant decrease in the E...           1.000000
# 9   Low- and middle-income countries such as Afric...           0.909354
# 10  Deepening engagement with global and regional ...           1.000000
# 11  Much of finaicial support is used to fund rese...                NaN
# 12  Yes.  It inculdes SDG indicator 3.d.2 and SDG ...           1.000000
# 13  Yes, new emerging antimicrobial resistance (AM...           1.000000
# 14  Yes. For example, the USA planed to strengthen...           1.000000
# 15        Guinea-Bissau, the UK, the USA, and Canada.           1.000000
# 16  Infections caused by antimicrobial-resistant E...           1.000000
# 17  Escherichia coli and Staphylococcus aureus are...           1.000000
#
#     context_recall  faithfulness  answer_relevancy
# 0              1.0      1.000000          0.974570
# 1              1.0      1.000000          0.965291
# 2              0.0      0.666667               NaN
# 3              1.0      1.000000               NaN
# 4              1.0      1.000000          1.000000
# 5              1.0      1.000000          0.977347
# 6              1.0      1.000000          0.976911
# 7              1.0      1.000000          0.927155
# 8              1.0      1.000000               NaN
# 9              1.0      1.000000               NaN
# 10             1.0      1.000000          0.977904
# 11             0.5      1.000000          0.900056
# 12             1.0      0.666667          0.971665
# 13             1.0      0.600000          0.947207
# 14             0.0      0.333333               NaN
# 15             0.0           NaN          0.000000
# 16             0.0      0.444444          0.924403
# 17             NaN           NaN          0.937083
